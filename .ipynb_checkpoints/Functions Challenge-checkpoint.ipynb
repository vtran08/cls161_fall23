# %% [markdown]
# # Functions Challenge
# ## Directions
#
# Building off of the dictionaries challenge, create a function that takes a Pleiades url as input and returns a dictionary with two pieces of information: "location_id" and "coordinates." For example, given the url `https://pleiades.stoa.org/places/423025/json` return the dictionary:
# `{'location_id': '423025', 'coordinates': [12.486137, 41.891775]}`
#
# Then, use a for loop to apply your function to the list of urls below building a new list of the returned dictionaries called `coordinates_list`. Your final result should look like this:
#
# `[{'location_id': '423025', 'coordinates': [12.486137, 41.891775]}, {'location_id': '550595', 'coordinates': [26.238889, 39.9575]}, {'location_id': '314921', 'coordinates': [10.312944, 36.847009]}, {'location_id': '60406/', 'coordinates': [71.06148, 29.2389543]}, {'location_id': '79574/', 'coordinates': [-0.088949, 51.513335]}]`
#
# Hint: The location id can be found in the url, you will need to isolate it somehow.
#
# Bonus task: Find the location name and include it in your dictionary.

# %% [markdown]
# ## Solution

# %%
import requests
import json

# %%
# How to use requests
url = "https://pleiades.stoa.org/places/423025/json"  # set your url
response = requests.get(url)  # use requests.get() to get a response object
text = response.text  # extract the text from the response object using the text attributeb

# %%
# The data you get from the pleiades url will techincally be a string even though it looks like a dictionary.
# You can use the json library to convert the string to a dictionary
data = json.loads(text)  # json.loads will convert the string to a dictionary. The "s" on the end of "loads" indicates a string

# %%
urls = [
    'https://pleiades.stoa.org/places/423025/json',
    'https://pleiades.stoa.org/places/550595/json',
    'https://pleiades.stoa.org/places/314921/json',
    'https://pleiades.stoa.org/places/60406/json',
    'https://pleiades.stoa.org/places/79574/json',
]

# %%
data
# Out:
# {'features': [{'geometry': {'type': 'Point',
#     'coordinates': [12.486137, 41.891775]},
#    'type': 'Feature',
#    'id': 'darmc-location-30635',
#    'properties': {'snippet': 'Settlement, ; 750 BC - AD 640',
#     'link': 'https://pleiades.stoa.org/places/423025/darmc-location-30635',
#     'description': '1:150,000 scale representative point location digitized from the Barrington Atlas of the Greek and Roman World by the Digital Atlas of Roman and Medieval Civilizations project at Harvard University.',
#     'location_precision': 'precise',
#     'title': 'DARMC location 30635'}}],
#  'contributors': [{'username': 'bkiesling',
#    'homepage': None,
#    'name': 'Brady Kiesling',
#    'uri': 'https://pleiades.stoa.org/author/bkiesling'},
#   {'username': 'sgillies',
#    'homepage': None,
#    'name': 'Sean Gillies',
#    'uri': 'https://pleiades.stoa.org/author/sgillies'},
#   {'username': 'jbecker',
#    'homepage': None,
#    'name': 'Jeffrey Becker',
#    'uri': 'https://pleiades.stoa.org/author/jbecker'},
#   {'username': 'thomase',
#    'homepage': None,
#    'name': 'Tom Elliott',
#    'uri': 'https://pleiades.stoa.org/author/thomase'},
#   {'username': None, 'name': 'DARMC'},
#   {'username': 'sebs',
#    'homepage': None,
#    'name': 'Sebastian Heath',
#    'uri': 'https://pleiades.stoa.org/author/sebs'},
#   {'username': 'juser',
#    'homepage': None,
#    'name': 'Joe User',
#    'uri': 'https://pleiades.stoa.org/author/juser'},
#   {'username': None, 'name': 'R. Talbert'}],
#  'locations': [{'contributors': [{'username': None, 'name': 'DARMC'},
#     {'username': None, 'name': 'R. Talbert'},
#     {'username': 'sgillies',
#      'homepage': None,
#      'name': 'Sean Gillies',
#      'uri': 'https://pleiades.stoa.org/author/sgillies'},
#     {'username': 'thomase',
#      'homepage': None,
#      'name': 'Tom Elliott',
#      'uri': 'https://pleiades.stoa.org/author/thomase'}],
#    'associationCertainty': 'certain',
#    'attestations': [{'timePeriod': 'archaic',
#      'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/archaic',
#      'confidence': 'confident',
#      'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'},
#     {'timePeriod': 'classical',
#      'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/classical',
#      'confidence': 'confident',
#      'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'},
#     {'timePeriod': 'hellenistic-republican',
#      'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/hellenistic-republican',
#      'confidence': 'confident',
#      'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'},
#     {'timePeriod': 'roman',
#      'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/roman',
#      'confidence': 'confident',
#      'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'},
#     {'timePeriod': 'late-antique',
#      'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/late-antique',
#      'confidence': 'confident',
#      'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'}],
#    'references': [{'alternateURI': '',
#      'accessURI': 'https://darmc.harvard.edu/',
#      'citationDetail': '30635',
#      'citationTypeURI': 'http://purl.org/spar/cito/citesAsDataSource',
#      'shortTitle': 'DARMC',
#      'bibliographicURI': 'https://www.zotero.org/groups/2533/pleiades/items/itemKey/9UD9W75C',
#      'formattedCitation': 'Michael McCormick, Giovanni Zambotti, Leland Grigoli, and Kelly Gibson, eds., The Digital Atlas of Roman and Medieval Civilizations (Cambridge (Massachusetts): Harvard University, 2007-), 30635.',
#      'otherIdentifier': ' ',
#      'type': 'citesAsDataSource'}],
#    'id': 'darmc-location-30635',
#    'featureTypeURI': ['https://pleiades.stoa.org/vocabularies/place-types/settlement',
#     'https://pleiades.stoa.org/vocabularies/place-types/'],
#    'end': 640,
#    'title': 'DARMC location 30635',
#    'provenance': 'DARMC OBJECTID: 30635',
#    'associationCertaintyURI': 'https://pleiades.stoa.org/vocabularies/association-certainty/certain',
#    'start': -750,
#    'locationTypeURI': ['https://pleiades.stoa.org/vocabularies/place-types/settlement',
#     'https://pleiades.stoa.org/vocabularies/place-types/'],
#    'archaeologicalRemains': 'unknown',
#    'details': 'DARMC OBJECTID: 30635',
#    'review_state': 'published',
#    'accuracy_value': 10.0,
#    'accuracy': 'https://pleiades.stoa.org/features/metadata/darmc-a',
#    'featureType': ['settlement', ''],
#    'description': '1:150,000 scale representative point location digitized from the Barrington Atlas of the Greek and Roman World by the Digital Atlas of Roman and Medieval Civilizations project at Harvard University.',
#    'created': '2011-08-02T21:07:57Z',
#    'geometry': {'type': 'Point', 'coordinates': [12.486137, 41.891775]},
#    'locationType': ['representative'],
#    'uri': 'https://pleiades.stoa.org/places/423025/darmc-location-30635',
#    'creators': [{'username': None, 'name': 'L. Quilici'},
#     {'username': None, 'name': 'S. Quilici Gigli'}],
#    '@type': 'Location',
#    'history': [{'comment': 'Edited',
#      'modifiedBy': 'jbecker',
#      'modified': '2014-02-16T15:11:30Z'},
#     {'comment': 'Global migration and reindexing of citations and provenance, February 2012',
#      'modifiedBy': 'admin',
#      'modified': '2012-02-15T04:56:44Z'},
#     {'action': 'Publish externally',
#      'modifiedBy': 'sgillies',
#      'modified': '2011-08-02T22:00:23Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'sgillies',
#      'modified': '2011-08-02T21:07:58Z'},
#     {'comment': "New locations, coordinates, and metadata from Harvard's DARMC project. See http://atlantides.org/trac/pleiades/wiki/PlaceUpgradesAndMigrations",
#      'modifiedBy': 'sgillies',
#      'modified': '2011-08-02T21:07:58Z'},
#     {'action': 'Create',
#      'modifiedBy': 'sgillies',
#      'modified': '2011-08-02T21:07:57Z'}]}],
#  'connections': [{'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:42Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Portuensis?',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/303999556',
#    'connectionType': 'connection',
#    'id': '303999556',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:43Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:43Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:42Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/303999556',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:43Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Aemilia Scauri',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/502042016',
#    'connectionType': 'connection',
#    'id': '502042016',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:43Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:43Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:43Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/502042016',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:43Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Latina',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/93042695',
#    'connectionType': 'connection',
#    'id': '93042695',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:45Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:45Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:43Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/93042695',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:45Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Cornelia',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/741499023',
#    'connectionType': 'connection',
#    'id': '741499023',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:45Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:45Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:45Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/741499023',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:45Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Nomentana',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/699256589',
#    'connectionType': 'connection',
#    'id': '699256589',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:45Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/699256589',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:46Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Ostiensis',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/390205932',
#    'connectionType': 'connection',
#    'id': '390205932',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/390205932',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:46Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Ardeatina',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/587835546',
#    'connectionType': 'connection',
#    'id': '587835546',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/587835546',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:46Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Tiburtina',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/272213281',
#    'connectionType': 'connection',
#    'id': '272213281',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/272213281',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:46Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Collatina',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/272213280',
#    'connectionType': 'connection',
#    'id': '272213280',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/272213280',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:46Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Campana?',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/231839930',
#    'connectionType': 'connection',
#    'id': '231839930',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:46Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/231839930',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:47Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Appia',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/356966898',
#    'connectionType': 'connection',
#    'id': '356966898',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/356966898',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:47Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Clodia',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/737328394',
#    'connectionType': 'connection',
#    'id': '737328394',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/737328394',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:47Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Aurelia',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/174900201',
#    'connectionType': 'connection',
#    'id': '174900201',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/174900201',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:47Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Cassia',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/447759107',
#    'connectionType': 'connection',
#    'id': '447759107',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/447759107',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:47Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Salaria',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/18271457',
#    'connectionType': 'connection',
#    'id': '18271457',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/18271457',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:47Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Flaminia',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/856514595',
#    'connectionType': 'connection',
#    'id': '856514595',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:47Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/856514595',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:48Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Praenestina',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/622606468',
#    'connectionType': 'connection',
#    'id': '622606468',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/622606468',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:48Z',
#    'associationCertainty': 'certain',
#    'title': 'Tiberis (river)',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/423080',
#    'connectionType': 'connection',
#    'id': '423080',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/423080',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:48Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Triumphalis',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/839719167',
#    'connectionType': 'connection',
#    'id': '839719167',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/839719167',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:48Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Sublacensis',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/188535571',
#    'connectionType': 'connection',
#    'id': '188535571',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/188535571',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:48Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Labicana',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/74935822',
#    'connectionType': 'connection',
#    'id': '74935822',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:48Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/74935822',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:49Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Francigena',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/136661131',
#    'connectionType': 'connection',
#    'id': '136661131',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:49Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:49Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:49Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/136661131',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': None,
#    'description': '',
#    'contributors': [],
#    'created': '2016-07-13T14:01:49Z',
#    'associationCertainty': 'certain',
#    'title': 'Via Laurentina',
#    'start': None,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/988280578',
#    'connectionType': 'connection',
#    'id': '988280578',
#    'attestations': [],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:49Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:49Z'},
#     {'action': 'Create',
#      'modifiedBy': 'admin',
#      'modified': '2016-07-13T14:01:49Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/988280578',
#    'details': '',
#    'references': [],
#    'review_state': 'published',
#    'creators': [{'username': 'admin',
#      'homepage': None,
#      'name': '',
#      'uri': 'https://pleiades.stoa.org/author/admin'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/connection'},
#   {'end': 640,
#    'description': '',
#    'contributors': [],
#    'created': '2017-12-04T03:08:42Z',
#    'associationCertainty': 'certain',
#    'title': 'Ager Romanus',
#    'start': -750,
#    'provenance': 'Pleiades',
#    'uri': 'https://pleiades.stoa.org/places/423025/ager-romanus',
#    'connectionType': 'part_of_regional',
#    'id': 'ager-romanus',
#    'attestations': [{'timePeriod': 'archaic',
#      'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/archaic',
#      'confidence': 'confident',
#      'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'},
#     {'timePeriod': 'classical',
#      'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/classical',
#      'confidence': 'confident',
#      'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'},
#     {'timePeriod': 'hellenistic-republican',
#      'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/hellenistic-republican',
#      'confidence': 'confident',
#      'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'},
#     {'timePeriod': 'roman',
#      'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/roman',
#      'confidence': 'confident',
#      'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'},
#     {'timePeriod': 'late-antique',
#      'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/late-antique',
#      'confidence': 'confident',
#      'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'}],
#    'history': [{'action': 'Publish externally',
#      'modifiedBy': 'jbecker',
#      'modified': '2021-10-04T21:17:17Z'},
#     {'action': 'Submit for review',
#      'modifiedBy': 'jbecker',
#      'modified': '2018-10-17T01:46:10Z'},
#     {'comment': 'cnxn',
#      'modifiedBy': 'jbecker',
#      'modified': '2017-12-04T03:08:43Z'},
#     {'action': 'Create',
#      'modifiedBy': 'jbecker',
#      'modified': '2017-12-04T03:08:42Z'}],
#    'connectsTo': 'https://pleiades.stoa.org/places/607225751',
#    'details': '',
#    'references': [{'alternateURI': '',
#      'accessURI': 'https://en.wikipedia.org',
#      'citationDetail': 'Ager Romanus',
#      'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#      'shortTitle': 'Wikipedia (English)',
#      'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/CI6F6W7W',
#      'formattedCitation': '<div class="csl-entry"><i>Wikipedia: The Free Encyclopedia That Anyone Can Edit</i>. Wikimedia Foundation, 2001. https://en.wikipedia.org.</div>',
#      'otherIdentifier': '',
#      'type': 'seeFurther'}],
#    'review_state': 'published',
#    'creators': [{'username': 'jbecker',
#      'homepage': None,
#      'name': 'Jeffrey Becker',
#      'uri': 'https://pleiades.stoa.org/author/jbecker'}],
#    '@type': 'Connection',
#    'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/part_of_regional'}],
#  'references': [{'alternateURI': '',
#    'accessURI': 'http://www.worldcat.org/oclc/43970336',
#    'citationDetail': '43 B2 Roma',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'BAtlas',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/MIAGQ5C6',
#    'formattedCitation': '<div class="csl-entry">Talbert, Richard J. A., ed. <i>Barrington Atlas of the Greek and Roman World</i>. Princeton, N.J.: Princeton University Press, 2000. http://www.worldcat.org/oclc/43970336.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': '',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Richardson 1992',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/SCISHZRH',
#    'formattedCitation': '<div class="csl-entry">Richardson, Lawrence. <i>A New Topographical Dictionary of Ancient Rome</i>. Baltimore: John Hopkins University Press, 1992.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'https://en.wikipedia.org/wiki/Ancient_Rome',
#    'citationDetail': 'Ancient Rome',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeAlso',
#    'shortTitle': 'Wikipedia (English)',
#    'bibliographicURI': 'https://www.zotero.org/groups/2533/items/CI6F6W7W',
#    'formattedCitation': 'Wikipedia: the free encyclopedia that anyone can edit (2001-), Ancient Rome.',
#    'otherIdentifier': ' ',
#    'type': 'seeAlso'},
#   {'alternateURI': '',
#    'accessURI': 'http://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.04.0006%3Aalphabetic+letter%3DR%3Aentry+group%3D2%3Aentry%3Droma',
#    'citationDetail': 'ROMA Italy',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'PECS (Perseus)',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/PV9N7BQD',
#    'formattedCitation': '<div class="csl-entry">Stillwell, Richard, William L MacDonald, and Marian Holland McAllister, eds. <i>The Princeton Encyclopedia of Classical Sites</i>. Princeton, N.J.: Princeton University Press, 1976. http://www.perseus.tufts.edu/hopper/text?doc=Perseus:text:1999.04.0006.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://www.cambridge.org/us/talbert/talbertdatabase/TPPlace1203.html',
#    'citationDetail': '4B5 (Talbert 1203)',
#    'citationTypeURI': 'http://purl.org/spar/cito/citesAsEvidence',
#    'shortTitle': 'TP (Talbert: CUP)',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/QT8GLGGI',
#    'formattedCitation': '<div class="csl-entry">Talbert, Richard. “Database: Peutinger Map Names and Features, with Commentary and User’s Guide.” In <i>Explore the Peutinger Map</i>. Cambridge UP, 2010. http://www.cambridge.org/us/talbert/talbertdatabase/prm.html.</div>',
#    'otherIdentifier': ' ',
#    'type': 'citesAsEvidence'},
#   {'alternateURI': '',
#    'accessURI': 'http://whc.unesco.org/en/list/91',
#    'citationDetail': '91: Historic Centre of Rome, the Properties of the Holy See in that City Enjoying Extraterritorial Rights and San Paolo Fuori le Mura',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'WHL',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/BIIFWTIR',
#    'formattedCitation': '<div class="csl-entry">UNESCO World Heritage Centre. <i>World Heritage List</i>, 1978. http://whc.unesco.org/en/list/.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.04.0064%3Aalphabetic+letter%3DR%3Aentry+group%3D4%3Aentry%3Droma-geo',
#    'citationDetail': 'ROMA',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Smith 1854 (Perseus)',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/BIA378QC',
#    'formattedCitation': '<div class="csl-entry">Smith, William. <i>Dictionary of Greek and Roman Geography</i>. London: Murray, 1854. http://www.perseus.tufts.edu/hopper/text?doc=Perseus:text:1999.04.0064.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://www.worldcat.org/oclc/813279761',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'LTUR',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/JC5ACZU7',
#    'formattedCitation': '<div class="csl-entry">Steinby, E.M., ed. <i>Lexicon Topographicum Urbis Romae</i>. 6 vols. Rome: Quasar, 2000. http://www.worldcat.org/oclc/813279761.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://www.worldcat.org/oclc/607676178',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'LTURS',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/7W77TJVH',
#    'formattedCitation': '<div class="csl-entry">La Regina, Adriano, ed. <i>Lexicon Topographicum Urbis Romae: Suburbium</i>. 5 vols. Rome: Quasar, 2001–2008. http://www.worldcat.org/oclc/607676178.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://www.perseus.tufts.edu/hopper/text?doc=Perseus:text:1999.04.0054',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Platner & Ashby 1929',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/H6XK259J',
#    'formattedCitation': '<div class="csl-entry">Platner, Samuel Ball, and Thomas Ashby. <i>A Topographical Dictionary of Ancient Rome</i>. London: Oxford University Press, 1929. http://penelope.uchicago.edu/Thayer/E/Gazetteer/Places/Europe/Italy/Lazio/Roma/Rome/_Texts/PLATOP*/home.html.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': '',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Carandini and Carafa 2012',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/QJUZMHGV',
#    'formattedCitation': '<div class="csl-entry">Carandini, Andrea, and Paolo Carafa, eds. <i>Atlante di Roma Antica</i>. Milan. 2 vols. Electa, n.d.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://digitalaugustanrome.org/',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': '',
#    'bibliographicURI': '',
#    'formattedCitation': 'Digital Augustan Rome',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': '',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Coarelli 2007',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/755TN8NV',
#    'formattedCitation': '<div class="csl-entry">Coarelli, Filippo. <i>Rome and Environs: An Archaeological Guide</i>. Berkeley: University of California Press, 2007.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://www.worldcat.org/oclc/768528944',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Claridge 2010',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/SA3KX3U2',
#    'formattedCitation': '<div class="csl-entry">Claridge, Amanda. <i>Rome: An Oxford Archaeological Guide</i>. 2nd ed. Oxford, England: Oxford University Press, 2010. http://www.worldcat.org/oclc/768528944.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': '',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Lugli 1952-1969',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/DXNIALBH',
#    'formattedCitation': '<div class="csl-entry">Lugli, Giuseppe, Universita di Roma, and Istituto di Topografia Antica. <i>Fontes ad topographiam veteris urbis Romae pertinentes</i>. 8 vols. Romae: Università di Roma . Istituto di Topografia Antica, 1952.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://www.jstor.org/stable/4475206',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Alföldi 1962',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/SGH5ELHQ',
#    'formattedCitation': '<div class="csl-entry">Alföldi, Andreas. “Ager Romanus Antiquus.” <i>Hermes</i> 90, no. 2 (1962): 187–213. http://www.jstor.org/stable/4475206.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://www.worldcat.org/oclc/793581620',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Taylor 2013',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/VDTB8E9N',
#    'formattedCitation': '<div class="csl-entry">Taylor, Lily Ross, and Jerzy Linderski. <i>The Voting Districts of the Roman Republic: The Thirty-Five Urban and Rural Tribes</i>. 2nd ed. 1 vols. Papers and Monographs of the American Academy in Rome 34. Ann Arbor: University of Michigan Press, 2013. http://www.worldcat.org/oclc/793581620.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://viaf.org/viaf/244992873',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/citesAsRelated',
#    'shortTitle': '',
#    'bibliographicURI': '',
#    'formattedCitation': 'viaf.org: 244992873',
#    'otherIdentifier': ' ',
#    'type': 'citesAsRelated'},
#   {'alternateURI': '',
#    'accessURI': 'http://nomisma.org/id/rome',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/citesAsRelated',
#    'shortTitle': '',
#    'bibliographicURI': '',
#    'formattedCitation': 'nomisma.org: Rome',
#    'otherIdentifier': ' ',
#    'type': 'citesAsRelated'},
#   {'alternateURI': '',
#    'accessURI': 'http://dbpedia.org/page/Ancient_Rome',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/citesAsRelated',
#    'shortTitle': '',
#    'bibliographicURI': '',
#    'formattedCitation': 'dbpedia.org: Ancient Rome',
#    'otherIdentifier': ' ',
#    'type': 'citesAsRelated'},
#   {'alternateURI': '',
#    'accessURI': 'http://collection.britishmuseum.org/resource?uri=http://collection.britishmuseum.org/id/place/x25706',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': '',
#    'bibliographicURI': '',
#    'formattedCitation': 'British Museum: Roma',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': 'http://www.encquran.brill.nl/entries/brill-s-new-pauly/rome-e1023950',
#    'accessURI': 'http://referenceworks.brillonline.com/browse/brill-s-new-pauly',
#    'citationDetail': 'Rome',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'New Pauly',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/DUTS58MJ',
#    'formattedCitation': '<div class="csl-entry">Hubert Cancik, Helmuth Schneider, Manfred Landfester, Christine F. Salazar, and Francis G. Gentry, eds. <i>Brill’s New Pauly: Encyclopaedia of the Ancient World.</i> Brill, 2015. http://referenceworks.brillonline.com/browse/brill-s-new-pauly.</div>',
#    'otherIdentifier': ' ',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://www.trismegistos.org/place/2058',
#    'citationDetail': 'GEO ID 2058: Rome',
#    'citationTypeURI': 'http://purl.org/spar/cito/citesAsRelated',
#    'shortTitle': 'TM',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/TN3GJAU8',
#    'formattedCitation': '<div class="csl-entry">Depauw, Mark, Tom Gheldof, Herbert Verreth, Nico Dogaer, Willy Clarysse, Yanne Broux, Gert Baetens, and Heinz-Josef Thissen. <i>Trismegistos: An Interdisciplinary Portal of the Ancient World</i>. Leuven, 2006. http://www.trismegistos.org/.</div>',
#    'otherIdentifier': ' ',
#    'type': 'citesAsRelated'},
#   {'alternateURI': '',
#    'accessURI': 'https://www.geonames.org/3169070/rome.html',
#    'citationDetail': '3169070: Rome',
#    'citationTypeURI': 'http://purl.org/spar/cito/citesAsRelated',
#    'shortTitle': 'GeoNames',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/IIFE4W6M',
#    'formattedCitation': '<div class="csl-entry">Marc Wick, and Christophe Boutreux. “GeoNames,” 2005. http://www.geonames.org/.</div>',
#    'otherIdentifier': ' ',
#    'type': 'citesAsRelated'},
#   {'alternateURI': '',
#    'accessURI': '',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Claridge and Holleran 2012',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/VID3QYCU',
#    'formattedCitation': '<div class="csl-entry">Claridge, Amanda, and Claire Holleran. <i>A Companion to the City of Rome</i>. Oxford: Wiley-Blackwell, 2012.</div>',
#    'otherIdentifier': '',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'http://www.worldcat.org/oclc/973795766',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Carandini and Carafa 2017',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/AHNCR4HJ',
#    'formattedCitation': '<div class="csl-entry">Carandini, Andrea, and Paolo Carafa, eds. <i>The Atlas of Ancient Rome\u202f: Biography and Portraits of the City</i>. 2 vols. Princeton, NJ: Princeton University Press, 2017. http://www.worldcat.org/oclc/973795766.</div>',
#    'otherIdentifier': '',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': '',
#    'citationDetail': '',
#    'citationTypeURI': 'http://purl.org/spar/cito/seeFurther',
#    'shortTitle': 'Erdkamp 2013',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/25BZ66UI',
#    'formattedCitation': '<div class="csl-entry">Erdkamp, Paul. <i>The Cambridge Companion to Ancient Rome</i>. Cambridge; New York: Cambridge University Press, 2013.</div>',
#    'otherIdentifier': '',
#    'type': 'seeFurther'},
#   {'alternateURI': '',
#    'accessURI': 'https://www.wikidata.org/wiki/Q220',
#    'citationDetail': 'Q220: Rome',
#    'citationTypeURI': 'http://purl.org/spar/cito/citesAsRelated',
#    'shortTitle': 'Wikidata',
#    'bibliographicURI': 'https://www.zotero.org/groups/pleiades/items/BCQIKDKS',
# ...
#   'https://pleiades.stoa.org/places/717263631',
#   'https://pleiades.stoa.org/places/777690772',
#   'https://pleiades.stoa.org/places/128044615',
#   'https://pleiades.stoa.org/places/697163696',
#   'https://pleiades.stoa.org/places/432336962',
#   'https://pleiades.stoa.org/places/268637493',
#   'https://pleiades.stoa.org/places/582254847',
#   'https://pleiades.stoa.org/places/593462325',
#   'https://pleiades.stoa.org/places/756231346',
#   'https://pleiades.stoa.org/places/45016678',
#   'https://pleiades.stoa.org/places/236573248',
#   'https://pleiades.stoa.org/places/484501230',
#   'https://pleiades.stoa.org/places/711164401',
#   'https://pleiades.stoa.org/places/711164402',
#   'https://pleiades.stoa.org/places/490093260',
#   'https://pleiades.stoa.org/places/749375794',
#   'https://pleiades.stoa.org/places/531536067',
#   'https://pleiades.stoa.org/places/236970356',
#   'https://pleiades.stoa.org/places/326532998',
#   'https://pleiades.stoa.org/places/508645486',
#   'https://pleiades.stoa.org/places/899108647',
#   'https://pleiades.stoa.org/places/606859979',
#   'https://pleiades.stoa.org/places/855441498',
#   'https://pleiades.stoa.org/places/161909278',
#   'https://pleiades.stoa.org/places/241048343',
#   'https://pleiades.stoa.org/places/700767827',
#   'https://pleiades.stoa.org/places/345477553',
#   'https://pleiades.stoa.org/places/158081395',
#   'https://pleiades.stoa.org/places/576179783',
#   'https://pleiades.stoa.org/places/557821256',
#   'https://pleiades.stoa.org/places/966985945',
#   'https://pleiades.stoa.org/places/600787940',
#   'https://pleiades.stoa.org/places/406470991',
#   'https://pleiades.stoa.org/places/188289894',
#   'https://pleiades.stoa.org/places/242008147',
#   'https://pleiades.stoa.org/places/250091860',
#   'https://pleiades.stoa.org/places/563029986',
#   'https://pleiades.stoa.org/places/524616090',
#   'https://pleiades.stoa.org/places/55302071',
#   'https://pleiades.stoa.org/places/305841487',
#   'https://pleiades.stoa.org/places/528606605',
#   'https://pleiades.stoa.org/places/387810362',
#   'https://pleiades.stoa.org/places/915004926',
#   'https://pleiades.stoa.org/places/915004927',
#   'https://pleiades.stoa.org/places/88851260',
#   'https://pleiades.stoa.org/places/851128106',
#   'https://pleiades.stoa.org/places/393959243',
#   'https://pleiades.stoa.org/places/529700371',
#   'https://pleiades.stoa.org/places/529700371',
#   'https://pleiades.stoa.org/places/954023893',
#   'https://pleiades.stoa.org/places/873367356',
#   'https://pleiades.stoa.org/places/894727084',
#   'https://pleiades.stoa.org/places/626333929',
#   'https://pleiades.stoa.org/places/345477552',
#   'https://pleiades.stoa.org/places/649091261',
#   'https://pleiades.stoa.org/places/728475463',
#   'https://pleiades.stoa.org/places/837078212',
#   'https://pleiades.stoa.org/places/108334324',
#   'https://pleiades.stoa.org/places/111763397',
#   'https://pleiades.stoa.org/places/260329424',
#   'https://pleiades.stoa.org/places/410440793',
#   'https://pleiades.stoa.org/places/670733375',
#   'https://pleiades.stoa.org/places/558953506',
#   'https://pleiades.stoa.org/places/964333742',
#   'https://pleiades.stoa.org/places/547584100',
#   'https://pleiades.stoa.org/places/300583267',
#   'https://pleiades.stoa.org/places/458808506',
#   'https://pleiades.stoa.org/places/267702570',
#   'https://pleiades.stoa.org/places/741137357',
#   'https://pleiades.stoa.org/places/267702571',
#   'https://pleiades.stoa.org/places/445192365',
#   'https://pleiades.stoa.org/places/865664297',
#   'https://pleiades.stoa.org/places/430827518',
#   'https://pleiades.stoa.org/places/182931391',
#   'https://pleiades.stoa.org/places/182931392',
#   'https://pleiades.stoa.org/places/541950317',
#   'https://pleiades.stoa.org/places/91325207',
#   'https://pleiades.stoa.org/places/251288970',
#   'https://pleiades.stoa.org/places/821658053',
#   'https://pleiades.stoa.org/places/303638861',
#   'https://pleiades.stoa.org/places/721487826',
#   'https://pleiades.stoa.org/places/721487827',
#   'https://pleiades.stoa.org/places/571005604',
#   'https://pleiades.stoa.org/places/217100040',
#   'https://pleiades.stoa.org/places/523965218',
#   'https://pleiades.stoa.org/places/70865871',
#   'https://pleiades.stoa.org/places/914715153',
#   'https://pleiades.stoa.org/places/152699900',
#   'https://pleiades.stoa.org/places/418356677',
#   'https://pleiades.stoa.org/places/711765706',
#   'https://pleiades.stoa.org/places/722890934',
#   'https://pleiades.stoa.org/places/554777911',
#   'https://pleiades.stoa.org/places/390937014',
#   'https://pleiades.stoa.org/places/114815757',
#   'https://pleiades.stoa.org/places/455817200',
#   'https://pleiades.stoa.org/places/445545537',
#   'https://pleiades.stoa.org/places/134485260',
#   'https://pleiades.stoa.org/places/910605204',
#   'https://pleiades.stoa.org/places/540898685',
#   'https://pleiades.stoa.org/places/100447491',
#   'https://pleiades.stoa.org/places/419380619',
#   'https://pleiades.stoa.org/places/355242955',
#   'https://pleiades.stoa.org/places/705506085',
#   'https://pleiades.stoa.org/places/27164982',
#   'https://pleiades.stoa.org/places/661181629',
#   'https://pleiades.stoa.org/places/281368358',
#   'https://pleiades.stoa.org/places/870073463',
#   'https://pleiades.stoa.org/places/770702014',
#   'https://pleiades.stoa.org/places/55607045',
#   'https://pleiades.stoa.org/places/207236501',
#   'https://pleiades.stoa.org/places/327838685',
#   'https://pleiades.stoa.org/places/422724245',
#   'https://pleiades.stoa.org/places/643547967',
#   'https://pleiades.stoa.org/places/307963010',
#   'https://pleiades.stoa.org/places/217953464',
#   'https://pleiades.stoa.org/places/981400960',
#   'https://pleiades.stoa.org/places/125119394',
#   'https://pleiades.stoa.org/places/851128107',
#   'https://pleiades.stoa.org/places/51787061',
#   'https://pleiades.stoa.org/places/319740268',
#   'https://pleiades.stoa.org/places/699284690',
#   'https://pleiades.stoa.org/places/327869515',
#   'https://pleiades.stoa.org/places/322942899',
#   'https://pleiades.stoa.org/places/867414858',
#   'https://pleiades.stoa.org/places/123625165',
#   'https://pleiades.stoa.org/places/958548506',
#   'https://pleiades.stoa.org/places/883684762',
#   'https://pleiades.stoa.org/places/971691208',
#   'https://pleiades.stoa.org/places/865014139',
#   'https://pleiades.stoa.org/places/594335209',
#   'https://pleiades.stoa.org/places/211668069',
#   'https://pleiades.stoa.org/places/823121346',
#   'https://pleiades.stoa.org/places/423089',
#   'https://pleiades.stoa.org/places/950724706',
#   'https://pleiades.stoa.org/places/816091000',
#   'https://pleiades.stoa.org/places/457581182',
#   'https://pleiades.stoa.org/places/817164756',
#   'https://pleiades.stoa.org/places/921692078',
#   'https://pleiades.stoa.org/places/948173334',
#   'https://pleiades.stoa.org/places/715215852',
#   'https://pleiades.stoa.org/places/423045',
#   'https://pleiades.stoa.org/places/866548110',
#   'https://pleiades.stoa.org/places/22073979',
#   'https://pleiades.stoa.org/places/986788581',
#   'https://pleiades.stoa.org/places/520255117',
#   'https://pleiades.stoa.org/places/740034026',
#   'https://pleiades.stoa.org/places/76960231',
#   'https://pleiades.stoa.org/places/159953179',
#   'https://pleiades.stoa.org/places/825969667',
#   'https://pleiades.stoa.org/places/103123065',
#   'https://pleiades.stoa.org/places/987367012',
#   'https://pleiades.stoa.org/places/915004925',
#   'https://pleiades.stoa.org/places/195092807',
#   'https://pleiades.stoa.org/places/226302607',
#   'https://pleiades.stoa.org/places/98504071',
#   'https://pleiades.stoa.org/places/378562727',
#   'https://pleiades.stoa.org/places/382995433',
#   'https://pleiades.stoa.org/places/97074052',
#   'https://pleiades.stoa.org/places/978725164',
#   'https://pleiades.stoa.org/places/165237927',
#   'https://pleiades.stoa.org/places/994615368',
#   'https://pleiades.stoa.org/places/173078007',
#   'https://pleiades.stoa.org/places/645216382',
#   'https://pleiades.stoa.org/places/463398873',
#   'https://pleiades.stoa.org/places/640011069',
#   'https://pleiades.stoa.org/places/914763973'],
#  'rights': 'Copyright © The Contributors. Sharing and remixing permitted under terms of the Creative Commons Attribution 3.0 License (cc-by).',
#  'created': '2018-06-07T19:48:13Z',
#  'uri': 'https://pleiades.stoa.org/places/423025',
#  'creators': [{'username': None, 'name': 'L. Quilici'},
#   {'username': None, 'name': 'S. Quilici Gigli'}],
#  '@type': 'Place',
#  'history': [{'comment': 'added iDAI.gazetteer reference',
#    'modifiedBy': 'jbecker',
#    'modified': '2021-10-20T19:33:15Z'},
#   {'comment': 'added Sauer 2021',
#    'modifiedBy': 'jbecker',
#    'modified': '2021-10-20T19:28:45Z'},
#   {'comment': 'Edited',
#    'modifiedBy': 'jbecker',
#    'modified': '2021-10-04T21:17:00Z'},
#   {'comment': 'Becker 2021',
#    'modifiedBy': 'jbecker',
#    'modified': '2021-10-02T14:57:29Z'},
#   {'comment': 'ctype',
#    'modifiedBy': 'jbecker',
#    'modified': '2021-01-01T15:49:48Z'},
#   {'comment': 'reference added Goodman 2020',
#    'modifiedBy': 'jbecker',
#    'modified': '2020-09-23T13:25:30Z'},
#   {'comment': 'references',
#    'modifiedBy': 'jbecker',
#    'modified': '2020-07-25T03:04:05Z'},
#   {'comment': 'Edited',
#    'modifiedBy': 'jbecker',
#    'modified': '2020-07-25T03:01:12Z'},
#   {'comment': 'Edited',
#    'modifiedBy': 'jbecker',
#    'modified': '2020-07-25T02:51:36Z'},
#   {'comment': 'Edited',
#    'modifiedBy': 'jbecker',
#    'modified': '2020-07-01T14:27:17Z'},
#   {'comment': 'Reynolds 1997',
#    'modifiedBy': 'jbecker',
#    'modified': '2020-07-01T14:25:21Z'},
#   {'comment': 'Arachne 8002160: Rom (Stadt gesamt) Roma, Rom (Metropolitanstadt)',
#    'modifiedBy': 'jbecker',
#    'modified': '2020-05-28T14:55:40Z'},
#   {'comment': 'Edited',
#    'modifiedBy': 'jbecker',
#    'modified': '2020-05-14T00:09:27Z'},
#   {'comment': 'changed ref types',
#    'modifiedBy': 'jbecker',
#    'modified': '2020-05-13T23:57:28Z'},
#   {'comment': 'references',
#    'modifiedBy': 'jbecker',
#    'modified': '2020-05-13T23:56:32Z'},
#   {'comment': 'Edited',
#    'modifiedBy': 'jbecker',
#    'modified': '2019-10-30T14:38:32Z'},
#   {'comment': 'references',
#    'modifiedBy': 'jbecker',
#    'modified': '2019-03-31T15:00:49Z'},
#   {'comment': 'add ToposText reference provided by bkiesling',
#    'modifiedBy': 'admin',
#    'modified': '2018-06-07T19:48:29Z'},
#   {'comment': 'Baseline created',
#    'modifiedBy': 'admin',
#    'modified': '2018-06-07T19:48:06Z'},
#   {'comment': 'Edited',
#    'modifiedBy': 'jbecker',
#    'modified': '2017-12-04T15:12:47Z'},
#   {'comment': 'RE Rom added',
#    'modifiedBy': 'jbecker',
#    'modified': '2017-12-04T15:11:58Z'},
#   {'comment': 'references',
#    'modifiedBy': 'jbecker',
#    'modified': '2017-12-04T03:24:04Z'},
#   {'comment': 'references',
#    'modifiedBy': 'jbecker',
#    'modified': '2017-12-04T03:21:22Z'},
#   {'comment': 'added reference',
#    'modifiedBy': 'jbecker',
#    'modified': '2016-11-07T02:23:12Z'},
#   {'comment': 'added references',
#    'modifiedBy': 'jbecker',
#    'modified': '2016-11-07T00:28:22Z'},
#   {'comment': 'added reference',
#    'modifiedBy': 'jbecker',
#    'modified': '2016-11-07T00:22:20Z'},
#   {'comment': 'added references',
#    'modifiedBy': 'jbecker',
#    'modified': '2016-10-30T01:31:14Z'},
#   {'comment': 'Edited',
#    'modifiedBy': 'jbecker',
#    'modified': '2016-07-19T17:21:25Z'},
#   {'comment': 'Edited',
#    'modifiedBy': 'jbecker',
#    'modified': '2016-07-08T18:46:12Z'},
#   {'comment': 'added references',
#    'modifiedBy': 'jbecker',
#    'modified': '2016-01-12T22:56:56Z'},
#   {'comment': 'added reference',
#    'modifiedBy': 'jbecker',
#    'modified': '2015-09-05T04:25:01Z'},
#   {'comment': 'added references',
#    'modifiedBy': 'jbecker',
#    'modified': '2015-09-05T04:19:37Z'},
#   {'comment': 'added references',
#    'modifiedBy': 'jbecker',
#    'modified': '2015-06-05T23:05:18Z'},
#   {'comment': 'added cnxn',
#    'modifiedBy': 'jbecker',
#    'modified': '2015-04-23T15:55:26Z'},
#   {'comment': 'added cnxn',
#    'modifiedBy': 'jbecker',
#    'modified': '2015-04-23T04:27:26Z'},
#   {'comment': 'added cnxn',
#    'modifiedBy': 'jbecker',
#    'modified': '2015-02-16T02:41:39Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2014-06-15T04:02:06Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2014-02-16T15:04:40Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-12-27T23:33:30Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-11-03T18:57:55Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-11-03T18:57:41Z'},
#   {'comment': 'added reference',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-10-29T02:12:05Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-09-01T23:16:27Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-08-18T17:16:21Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-07-14T17:47:36Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-07-12T17:23:25Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-07-01T20:38:16Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-06-29T17:59:30Z'},
#   {'comment': 'added connection',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-06-28T18:06:32Z'},
#   {'comment': 'edited references',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-04-14T15:49:28Z'},
#   {'comment': 'added references',
#    'modifiedBy': 'jbecker',
#    'modified': '2013-02-02T18:15:42Z'},
#   {'comment': 'Edited',
#    'modifiedBy': 'jbecker',
#    'modified': '2012-12-07T19:36:37Z'},
#   {'comment': 'updated references',
#    'modifiedBy': 'jbecker',
#    'modified': '2012-12-07T19:36:06Z'},
#   {'comment': 'edited UNESCO reference to meet new format guidelines',
#    'modifiedBy': 'jbecker',
#    'modified': '2012-11-14T17:10:34Z'},
#   {'comment': 'DARE feature tag fix.',
#    'modifiedBy': 'sgillies',
#    'modified': '2012-10-23T19:44:28Z'},
#   {'comment': "Location updates and tags from Johan Ahlfeldt's (jahlfeldt) Digital Atlas of the Roman Empire in October 2012",
#    'modifiedBy': 'sgillies',
#    'modified': '2012-10-20T23:46:01Z'},
#   {'comment': 'Edited',
#    'modifiedBy': 'jbecker',
#    'modified': '2012-10-18T19:57:41Z'},
#   {'comment': 'added category',
#    'modifiedBy': 'jbecker',
#    'modified': '2012-10-18T19:57:00Z'},
#   {'comment': 'Global migration and reindexing of citations and provenance, February 2012',
#    'modifiedBy': 'admin',
#    'modified': '2012-02-15T04:56:43Z'},
#   {'comment': 'remove comma from description',
#    'modifiedBy': 'sgillies',
#    'modified': '2012-02-04T23:38:49Z'},
#   {'comment': 'Change description, type, add reference',
#    'modifiedBy': 'sgillies',
#    'modified': '2012-02-04T23:38:08Z'},
#   {'comment': 'Add connection to Tiberis and expand types',
#    'modifiedBy': 'sgillies',
#    'modified': '2011-09-27T23:30:41Z'},
#   {'comment': "New locations, coordinates, and metadata from Harvard's DARMC project. See http://atlantides.org/trac/pleiades/wiki/PlaceUpgradesAndMigrations",
#    'modifiedBy': 'sgillies',
#    'modified': '2011-08-02T21:07:58Z'},
#   {'comment': 'Temple of Vesta provides a good coordinate pair.',
#    'modifiedBy': 'thomase',
#    'modified': '2011-02-23T17:35:43Z'},
#   {'comment': 'Baseline created',
#    'modifiedBy': 'sebs',
#    'modified': '2011-01-24T17:57:25Z'},
#   {'comment': 'Baseline created',
#    'modifiedBy': 'juser',
#    'modified': '2011-01-24T17:51:17Z'},
#   {'comment': 'Baseline created',
#    'modifiedBy': 'sgillies',
#    'modified': '2011-01-24T17:39:53Z'},
#   {'comment': 'Detail text updated from former modernLocation. See http://atlantides.org/trac/pleiades/wiki/PlaceDetailsUpgrade',
#    'modifiedBy': 'sgillies',
#    'modified': '2011-01-14T19:44:32Z'},
#   {'action': 'Publish externally',
#    'modifiedBy': 'thomase',
#    'modified': '2010-11-11T05:13:04Z'},
#   {'action': 'Submit for review',
#    'modifiedBy': 'sgillies',
#    'modified': '2010-11-10T22:39:18Z'},
#   {'action': 'Create',
#    'modifiedBy': 'sgillies',
#    'modified': '2010-11-10T22:33:36Z'}]}

# %% [markdown]
# # Solution

# %%
def get_coordinates(url):
    
    """Getting information from url"""
    response = requests.get(url)  
    text = response.text
    data = json.loads(text)
    
    """Parsing Location ID"""
    id = url.split('/')
    location_id = id[4]
    
    """Getting coordinates and making dictionary"""
    longitude = data['features'][0]['geometry']['coordinates'][1]
    latitude = data['features'][0]['geometry']['coordinates'][0]
    coordinates = (f"[{latitude}, {longitude}]")
    
    new_dictionary = {'location_id': location_id, 'coordinates': coordinates}
    
    return new_dictionary

# %%
coordinates_list = []

for url in urls:
    coordinates_list.append(get_coordinates(url))

print(coordinates_list)
# Out:
# [{'location_id': '423025', 'coordinates': '[12.486137, 41.891775]'}, {'location_id': '550595', 'coordinates': '[26.238889, 39.9575]'}, {'location_id': '314921', 'coordinates': '[10.323056, 36.853056]'}, {'location_id': '60406', 'coordinates': '[71.06148, 29.2389543]'}, {'location_id': '79574', 'coordinates': '[-0.088949, 51.513335]'}]
